# %% [markdown]
# <a href="https://colab.research.google.com/github/tarunn107/EDA/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df = pd.read_csv('/content/drive/MyDrive/Santa/GlobalTerrorismData.csv', encoding='latin-1')
pd.set_option('display.max_columns', None)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
df1=pd.DataFrame(df[['iyear','imonth','iday','region_txt','country_txt','city','attacktype1_txt','success','suicide','targtype1_txt','weaptype1_txt','targsubtype1_txt','gname','individual','propvalue','ishostkid','ransompaid','nkill','nwound']])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   iyear             181691 non-null  int64
#  1   imonth            181691 non-null  int64
#  2   iday              181691 non-null  int64
#  3   region_txt        181691 non-null  object
#  4   country_txt       181691 non-null  object
#  5   city              181257 non-null  object
#  6   attacktype1_txt   181691 non-null  object
#  7   success           181691 non-null  int64
#  8   suicide           181691 non-null  int64
#  9   targtype1_txt     181691 non-null  object
#  10  weaptype1_txt     181691 non-null  object
#  11  targsubtype1_txt  171318 non-null  object
#  12  gname             181691 non-null  object
#  13  individual        181691 non-null  int64
#  14  propvalue         38989 non-null   float64
#  15  ishostkid         181513 non-null  float64
# ...

# %%
df1.rename(columns = {'iyear':'year','imonth':'month','iday':'day','region_txt':'Region','nwound':'wounded','nkill':'killed','country_txt':'Country','attacktype1_txt':'Type_of_attack','weaptype1_txt':'weapon','targtype1_txt':'target','targsubtype1_txt':'target_subtype','gname':'attacker_name'}, inplace = True)
df1['casualities']=df1['wounded']+df1['killed']

# %%
df1['wounded'] = df1['wounded'].fillna(0).astype(int)
df1['killed'] = df1['killed'].fillna(0).astype(int)

df1.columns
# Out:
# Index(['year', 'month', 'day', 'Region', 'Country', 'city', 'Type_of_attack',
#        'success', 'suicide', 'target', 'weapon', 'target_subtype',
#        'attacker_name', 'individual', 'propvalue', 'ishostkid', 'ransompaid',
#        'killed', 'wounded', 'casualities'],
#       dtype='object')

# %%
df1['attacker_name'].value_counts()
top_attackers=pd.DataFrame(df1['attacker_name'].value_counts().reset_index())
top_attackers.columns=['organistation','number_of_attacks']
top_attackers
# Out:
#                                          organistation  number_of_attacks
# 0                                              Unknown              82782
# 1                                              Taliban               7478
# 2          Islamic State of Iraq and the Levant (ISIL)               5613
# 3                                    Shining Path (SL)               4555
# 4     Farabundo Marti National Liberation Front (FMLN)               3351
# ...                                                ...                ...
# 3532                                    Ansar Sarallah                  1
# 3533                                    Sword of Islam                  1
# 3534             Support of Ocalan-The Hawks of Thrace                  1
# 3535                          Arab Revolutionary Front                  1
# 3536                                            MANO-D                  1
#
# [3537 rows x 2 columns]

# %%
a=df1[df1['attacker_name']=='Taliban']['weapon'].value_counts()
a=a.drop(labels=['Unknown'])
a=a.iloc[:4]
fig = plt.figure(figsize =(10, 7))
plt.pie(a,labels=list(a.index),autopct='%1.1f%%',startangle=90,explode=(0.01, 0.01, 0.2, 0.3))
plt.title('Top 4 weapons of choice of')
plt.show()

# %%
def top4xofy(str1,str2,str3):
  a=df1[df1[str1]==str2][str3].value_counts()
  a=a.iloc[:4]
  fig = plt.figure(figsize =(10, 7))
  plt.pie(a,labels=list(a.index),autopct='%1.1f%%',startangle=90,explode=(0.01, 0.01, 0.2, 0.3))
  plt.show() 
top4xofy('attacker_name','Islamic State of Iraq and the Levant (ISIL)','Country')

# %%
# Out:
# Explosives    48945
# Firearms      23539
# Incendiary     4634
# Unknown        4152
# Melee          1186
# Name: weapon, dtype: int64
