# %% [markdown]
# <a href="https://colab.research.google.com/github/tarunn107/EDA/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df = pd.read_csv('/content/drive/MyDrive/Santa/GlobalTerrorismData.csv', encoding='latin-1')
pd.set_option('display.max_columns', None)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
df1=pd.DataFrame(df[['iyear','imonth','iday','region_txt','country_txt','city','attacktype1_txt','success','suicide','targtype1_txt','targsubtype1_txt','gname','individual','nwound','propvalue','ishostkid','ransompaid']])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   iyear             181691 non-null  int64
#  1   imonth            181691 non-null  int64
#  2   iday              181691 non-null  int64
#  3   region_txt        181691 non-null  object
#  4   country_txt       181691 non-null  object
#  5   city              181257 non-null  object
#  6   attacktype1_txt   181691 non-null  object
#  7   success           181691 non-null  int64
#  8   suicide           181691 non-null  int64
#  9   targtype1_txt     181691 non-null  object
#  10  targsubtype1_txt  171318 non-null  object
#  11  gname             181691 non-null  object
#  12  individual        181691 non-null  int64
#  13  nwound            165380 non-null  float64
#  14  propvalue         38989 non-null   float64
#  15  ishostkid         181513 non-null  float64
# ...

# %%
df1.rename(columns = {'iyear':'year','imonth':'month','iday':'day','region_txt':'Region','country_txt':'Country','attacktype1_txt':'Type of attack','targtype1_txt':'Target','targsubtype1_txt':'Target subtype','gname':'Attacker name'}, inplace = True)
df1.head()
# Out:
#    year  month  day                       Region             Country  \
# 0  1970      7    2  Central America & Caribbean  Dominican Republic
# 1  1970      0    0                North America              Mexico
# 2  1970      1    0               Southeast Asia         Philippines
# 3  1970      1    0               Western Europe              Greece
# 4  1970      1    0                    East Asia               Japan
#
#             city                  Type of attack  success  suicide  \
# 0  Santo Domingo                   Assassination        1        0
# 1    Mexico city     Hostage Taking (Kidnapping)        1        0
# 2        Unknown                   Assassination        1        0
# 3         Athens               Bombing/Explosion        1        0
# 4        Fukouka  Facility/Infrastructure Attack        1        0
#
#                         Target  \
# 0  Private Citizens & Property
# 1      Government (Diplomatic)
# 2          Journalists & Media
# ...

# %%
# Out:
# 15    6500
# 1     6344
# 4     6153
# 16    6112
# 10    6064
# 9     6057
# 13    6043
# 14    6028
# 28    6027
# 12    6012
# 3     6011
# 7     5997
# 19    5973
# 2     5954
# 27    5937
# 11    5936
# 20    5930
# 18    5880
# 25    5875
# 8     5859
# 17    5852
# 5     5844
# 21    5827
# 26    5823
# 22    5799
# 23    5782
# 6     5781
# 24    5752
# 29    5507
# 30    5046
# 31    3095
# 0      891
# Name: day, dtype: int64
